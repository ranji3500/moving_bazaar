# %%
import mysql.connector
from mysql.connector import pooling

# %%
class MySQLDatabase:
    def __init__(self, host, database, user, password, pool_name="mypool", pool_size=5):
        """
        Initialize the MySQL database connection pool.
        """
        self.connection_pool = mysql.connector.pooling.MySQLConnectionPool(
            pool_name=pool_name,
            pool_size=pool_size,
            host=host,
            database=database,
            user=user,
            password=password,
        )

    def call_procedure(self, proc_name, args=None):
        """
        Call a stored procedure and handle its output.
        Args:
            proc_name (str): The name of the stored procedure.
            args (tuple): The arguments for the procedure.
        Returns:
            list or str: A list of results for SELECT operations or a single message for status operations.
        """
        connection = self.connection_pool.get_connection()
        try:
            cursor = connection.cursor()
            if args:
                cursor.callproc(proc_name, args)
            else:
                cursor.callproc(proc_name)

            # Retrieve output parameters or results
            results = []
            for result in cursor.stored_results():
                results.append(result.fetchall())

            # Check if there are OUT parameters
            if args and cursor.rowcount == -1:  # For OUT parameters
                return args

            return results

        except mysql.connector.Error as err:
            print(f"Error: {err}")
        finally:
            cursor.close()
            connection.close()

    def insert_data(self, proc_name, args):
        """
        Insert data using the specified stored procedure.
        Args:
            proc_name (str): Name of the stored procedure for insertion.
            args (tuple): Arguments to be passed to the procedure.
        Returns:
            str: Return message from the procedure.
        """
        result = self.call_procedure(proc_name, args)
        if result:
            print(f"Procedure `{proc_name}` executed successfully.")
            return result
        return "Procedure execution failed."

    def get_table_data(self, proc_name, args=None):
        """
        Retrieve table data using the specified stored procedure.
        Args:
            proc_name (str): Name of the stored procedure for retrieval.
            args (tuple): Arguments to be passed to the procedure.
        Returns:
            list: A list of rows fetched from the procedure.
        """
        results = self.call_procedure(proc_name, args)
        if results:
            print(f"Procedure `{proc_name}` executed successfully.")
            return results[0] if results else []
        return []

# %%
# Initialize the MySQLDatabase object
db = MySQLDatabase(
    host="localhost",
    database="root",
    user="root",
    password="moving_bazzar"
)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\connection_cext.py:335, in CMySQLConnection._open_connection(self)
#     334 try:
# --> 335     self._cmysql.connect(**cnx_kwargs)
#     336     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Initialize the MySQLDatabase object
# ----> 2 db = MySQLDatabase(
#       3     host="localhost",
#       4     database="root",
#       5     user="root",
#       6     password="moving_bazzar"
#       7 )
#
# Cell In[8], line 6, in MySQLDatabase.__init__(self, host, database, user, password, pool_name, pool_size)
#       2 def __init__(self, host, database, user, password, pool_name="mypool", pool_size=5):
#       3     """
#       4     Initialize the MySQL database connection pool.
#       5     """
# ----> 6     self.connection_pool = mysql.connector.pooling.MySQLConnectionPool(
#       7         pool_name=pool_name,
#       8         pool_size=pool_size,
#       9         host=host,
#      10         database=database,
#      11         user=user,
#      12         password=password,
#      13     )
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\pooling.py:490, in MySQLConnectionPool.__init__(self, pool_size, pool_name, pool_reset_session, **kwargs)
#     488 cnt = 0
#     489 while cnt < self._pool_size:
# --> 490     self.add_connection()
#     491     cnt += 1
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\pooling.py:613, in MySQLConnectionPool.add_connection(self, cnx)
#     610     raise PoolError("Failed adding connection; queue is full")
#     612 if not cnx:
# --> 613     cnx = connect(**self._cnx_config)  # type: ignore[assignment]
#     614     try:
#     615         if (
#     616             self._reset_session
#     617             and self._cnx_config["compress"]
#     618             and cnx.get_server_version() < (5, 7, 3)
#     619         ):
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# --> 322     return CMySQLConnection(*args, **kwargs)
#     323 return MySQLConnection(*args, **kwargs)
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\connection_cext.py:151, in CMySQLConnection.__init__(self, **kwargs)
#     149 if kwargs:
#     150     try:
# --> 151         self.connect(**kwargs)
#     152     except Exception:
#     153         self.close()
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\abstracts.py:1426, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1423     self.config(**kwargs)
#    1425 self.disconnect()
# -> 1426 self._open_connection()
#    1428 charset, collation = (
#    1429     kwargs.pop("charset", None),
#    1430     kwargs.pop("collation", None),
#    1431 )
#    1432 if charset or collation:
#
# File ~\.conda\envs\moving_bazaar\lib\site-packages\mysql\connector\connection_cext.py:340, in CMySQLConnection._open_connection(self)
#     338         self.converter.str_fallback = self._converter_str_fallback
#     339 except MySQLInterfaceError as err:
# --> 340     raise get_mysql_exception(
#     341         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     342     ) from err
#     344 self._do_handshake()
#     346 if (
#     347     not self._ssl_disabled
#     348     and hasattr(self._cmysql, "get_ssl_cipher")
#    (...)
#     353
#     354     # `get_ssl_cipher()` returns the name of the cipher being used.
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %%
 # Example 1: Insert data and get a message
    result_msg = db.insert_data("insert_data", ("John Doe", 30))  # Procedure name and args
    print("Insert Procedure Response:", result_msg)

    # Example 2: Retrieve data from the table
    data = db.get_table_data("get_all_data")  # Procedure name
    print("Table Data:")
    for row in data:
        print(row)
